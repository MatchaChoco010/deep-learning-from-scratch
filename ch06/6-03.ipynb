# %% [markdown]
# # 6章

# %% [markdown]
# ## Batch Normalization

# %% [markdown]
# 活性化関数の結果が適度な広がりを持つことが大事だった。
#
# 活性化関数の結果が適度な広がりを持つように活性化関数に入力する前もしくは後に調整を行うレイヤを挿入する手法がBatch Normalization。
# これによって学習係数を大きくできたり、初期値への依存が減ったり、過学習を抑制できたりといいことばかり。

# %% [markdown]
# ミニバッチ$B=\{x_1, x_2, \cdots, x_m\}$という$m$個のデータが流れるときについて。
#
# $$
# \mu_B \leftarrow \frac{1}{m}\sum_{i=1}^{m}x_i
# $$
#
# $$
# \sigma_B^2 \leftarrow \frac{1}{m}\sum_{i=1}^{m}(x_i - \mu_B)^2
# $$
#
# $$
# \hat{x_i} \leftarrow \frac{x_i - \mu_B}{\sqrt{\sigma_B^2 + \epsilon}}
# $$
#
# として$x_i$に変換をしてやることで平均0で分散が1の分布になる。
# この分布にさらに適当なスケールとシフトの変換を行う。
#
# $$
# y_i \leftarrow \gamma \hat{x_i} + \beta
# $$
#
# $\gamma$と$\beta$はそれぞれ1と0からスタートして学習するパラメータ。
# これによって適切な分布に変換されることになるので、初期値にそれほど神経質になる必要がなくなる。
# 逆伝播も頑張れば求められる。

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 学習データを削減
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 3.グラフの描画==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

plt.figure(figsize = (15, 15))

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.097 - 0.094
# epoch:1 | 0.097 - 0.099
# ..\common\functions.py:34: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=0)
# ..\common\layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# C:\Users\itsuki\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# epoch:2 | 0.097 - 0.136
# epoch:3 | 0.097 - 0.154
# epoch:4 | 0.097 - 0.191
# epoch:5 | 0.097 - 0.201
# epoch:6 | 0.097 - 0.227
# epoch:7 | 0.097 - 0.239
# epoch:8 | 0.097 - 0.258
# epoch:9 | 0.097 - 0.285
# epoch:10 | 0.097 - 0.289
# epoch:11 | 0.097 - 0.319
# epoch:12 | 0.097 - 0.323
# epoch:13 | 0.097 - 0.347
# epoch:14 | 0.097 - 0.354
# epoch:15 | 0.097 - 0.366
# epoch:16 | 0.097 - 0.365
# epoch:17 | 0.097 - 0.382
# epoch:18 | 0.097 - 0.391
# epoch:19 | 0.097 - 0.407
# ...

# %% [markdown]
# 初期値の標準偏差を様々なパターンにしてBatch Normalizationの有りと無しで比較をしている。
# Batch Normalizationがない場合は標準偏差がちょうどよいあたりでしか学習が進まない。
